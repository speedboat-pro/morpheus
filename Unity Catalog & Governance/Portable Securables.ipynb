-- %%
%python
df = spark.sql(f"SHOW GRANTS on silver")
display(df)
%python
df.createOrReplaceTempView("temp")

SELECT concat('GRANT ', ActionType, ' ON ', ObjectType, ' TO ', Principal,';') from temp

-- %%
GRANT EXECUTE ON CATALOG ctlg_db_training_12052025 TO `account users`;
GRANT READ VOLUME ON CATALOG ctlg_db_training_12052025 TO `account users`;
GRANT SELECT ON CATALOG ctlg_db_training_12052025 TO `account users`;
GRANT USE CATALOG ON CATALOG ctlg_db_training_12052025 TO `account users`;
